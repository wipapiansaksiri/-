# %%
my_input = [1, 2, 3, 4, 5]
 
print(f'Current Numbers List {my_input}')
 
number = int(input("Please enter a number to be added:\n"))
 
index = int(input(f'Enter the index between 0 and {len(my_input) - 1} to add the given number:\n'))
 
my_input.insert(index, number)
 
print(f'Updated List {my_input}')
# Out:
# Current Numbers List [1, 2, 3, 4, 5]
# Please enter a number to be added:
# 3
# Enter the index between 0 and 4 to add the given number:
# 20
# Updated List [1, 2, 3, 4, 5, 3]

# %%
def add_menu():
  id = ['C01','C02','C03','C04','C05','B01']
  menu = ['Americano','Espresso','Capuccino','Moocca','Latte','Bakery']
  price = [55,60,60,65,70,45]
  select = input('Enter Menu : ').upper()
  if select in id:
    i = id.index(select)
    quantity = int(input('Enter quantity : '))
    menulist.append((menu[i],quantity,price[i]))
  else:
    print('menu not found!')

def receipt(menulist,member = -1):
  total = 0
  print()   
  print("."*47)
  print("                   Cafe                    ")
  print("                  Receipt                       ")
  print("."*47)
  print("Menu                   QTY                Price ")
  for line in menulist:
    price = line[1]*line[2]
    print("%-22s %-19d %d" %(line[0],line[1],price))
    total = total + price
  print("."*47)
  point = total//100
  if member != -1:
    if int(member_point[member]) >= 10:
      print('you have more 10 point')
      discount = input('change to discount 10point = 50thb (Y/N) : ').upper()
      while discount != 'Y' and discount != 'N':
        discount = input('change to discount 10point = 50thb (Y/N) : ').upper()
      if discount == 'Y':
        member_point[member] = int(member_point[member]) - 10
        print('%-42 $s'%('Discount',f'{total} - 50)'))
        total = total - 50


  print('%-42s %s'%('Price',total))
  print('%-42s %s'%('Total',total+(total*0.07)))
  print('%-42s %.2f'%('Vat',total*0.07))
  if member != -1:
    lastpoint = int(member_point[member])+point
    print('%-42s %s'%('Point',point))
    # print(member_name[member],member_point[member])

    print('member : %s point : %s + %s = %s'%(member_name[member],member_point[member],point,lastpoint))
    member_point[member] = lastpoint

    with open('member.txt','w') as file:
      for i in range(len(member_id)):
        file.write('%s %s %s\n'%(member_id[i],member_name[i],member_point[i]))
  




def register():
  with open('member.txt','r') as file:
    data = file.read().splitlines()
    if data !=  []:
      data = data[-1].split()
      data = data[0]
    else:
      data = 0000

      
      
  name = input('Enter name :')
  confirm = input('confirm (Y/N): ').upper()
  while confirm != 'Y' and confirm != 'N':
    print('try again!')
    confirm = input('confirm (Y/N): ').upper()

  if confirm == 'Y':
    with open('member.txt','a') as file:
      file.write('%.4d %s %s \n'%(int(data)+1,name,0))
      print('Your id is : ',int(data)+1)
      print('Register complete')



a = open('member.txt','a+')
a.close()

menu = ''
while menu != 'E':
  if menu == '1':
    print("."*47)
    print("                  Cafe ")
    print("                  Menu ")
    print("."*47)
    print("Menu ID         Menu                     Price  ")
    print("C01             Americano                 55    ")
    print("C02             Espresso                  60    ")
    print("C03             Cappuccino                60    ")
    print("C04             Mocca                     65    ")
    print("C05             Latte                     70    ")
    print("B01             Bakery                    45    ")
    print("."*47)
    ####code
    menu = ''
    menulist = []
    member_id = []
    member_name = []
    member_point = []
    with open('member.txt','r') as file:
      data = file.read().splitlines()
      for i in data:
        item = i.split()
        member_id.append(item[0])
        member_name.append(item[1])
        member_point.append(item[2])

    menu = ''
    while menu != 'Y':
      add_menu()
      menu = input('Quit(Y/N) : ').upper()

    member = input('Cafe Member Card (Y/N) : ').upper()
    while member != 'Y' and member != 'N':
      member = input('Cafe Member Card (Y/N) : ').upper()

    if member == 'Y':
      id = input('Enter your id : ')
      if id in member_id:
        i = member_id.index(id)
        receipt(menulist,i)
      else:
        print('Not Found')
    else:
      receipt(menulist)


  elif menu == '2':
    register()
  


  print('Menu')
  print('[1] order')
  print('[2] register')
  print('[E] exit')

  menu = input('Enter your menu : ').upper()
# Out:
# Menu
# [1] order
# [2] register
# [E] exit
# Enter your menu : 1
# ...............................................
#                   Cafe
#                   Menu
# ...............................................
# Menu ID         Menu                     Price
# C01             Americano                 55
# C02             Espresso                  60
# C03             Cappuccino                60
# C04             Mocca                     65
# C05             Latte                     70
# B01             Bakery                    45
# ...............................................
# Enter Menu : c03
# Enter quantity : 3
# Quit(Y/N) : y
# Cafe Member Card (Y/N) : y
# Enter your id : 001
# Not Found
# Menu
# [1] order
# [2] register
# [E] exit
# Enter your menu : 2
# Enter name :wipa
# confirm (Y/N): y
# Your id is :  1
# Register complete
# Menu
# [1] order
# [2] register
# [E] exit
# Enter your menu : 1
# ...............................................
# ...

# %%
void main() {
int temp[2] = {3,20};
int i;
for (i=0; i<2; i++)
printf("Day %d -> %d\n", i+1, sec[i]);
}
# Out:
#   File "<ipython-input-1-b522cdd8be64>", line 1
#     void main() {
#             ^
# SyntaxError: invalid syntax
